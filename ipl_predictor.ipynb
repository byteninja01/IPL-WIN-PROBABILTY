# %%
import numpy as np
import pandas as pd

# %%
matchs = pd.read_csv('matches.csv')
delivery = pd.read_csv('deliveries.csv')

# %%
matchs.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
matchs.shape
# Out:
# (1095, 20)

# %%
delivery.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore   0.0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore   0.0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore   0.0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore   0.0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore   0.0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0   1.0   SC Ganguly  P Kumar  BB McCullum           0.0         1.0
# 1   2.0  BB McCullum  P Kumar   SC Ganguly           0.0         0.0
# 2   3.0  BB McCullum  P Kumar   SC Ganguly           0.0         1.0
# 3   4.0  BB McCullum  P Kumar   SC Ganguly           0.0         0.0
# 4   5.0  BB McCullum  P Kumar   SC Ganguly           0.0         0.0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...

# %%
total_score_df = delivery.groupby(['match_id', 'inning'])['total_runs'].sum().reset_index()

# %%
total_score_df = total_score_df[total_score_df['inning']== 2]

# %%
matchs["team1"].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Mumbai Indians', 'Kolkata Knight Riders',
#        'Rajasthan Royals', 'Deccan Chargers', 'Chennai Super Kings',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Gujarat Lions', 'Rising Pune Supergiants',
#        'Rising Pune Supergiant', 'Delhi Capitals', 'Punjab Kings',
#        'Lucknow Super Giants', 'Gujarat Titans',
#        'Royal Challengers Bengaluru'], dtype=object)

# %%
teams = [
    'Sunrisers Hyderabad',
    'Mumbai Indians',
    'Royal Challengers Bangalore',
    'Kolkata Knight Riders',
    'Punjab Kings',
    'Chennai Super Kings',
    'Rajasthan Royals',
    'Delhi Capitals',
    'Gujarat Titans',
    'Lucknow Super Giants'
]

# %%
matchs['team1'] = matchs['team1'].str.replace('Delhi Daredevils', 'Delhi Capitals')
matchs['team2'] = matchs['team2'].str.replace('Delhi Daredevils', 'Delhi Capitals')

matchs['team1'] = matchs['team1'].str.replace('Deccan Chargers', 'Sunrisers Hyderabad')
matchs['team2'] = matchs['team2'].str.replace('Deccan Chargers', 'Sunrisers Hyderabad')

matchs['team1'] = matchs['team1'].str.replace('Kings XI Punjab', 'Punjab Kings')
matchs['team2'] = matchs['team2'].str.replace('Kings XI Punjab', 'Punjab Kings')

# %%
matchs = matchs[matchs['team1'].isin(teams)]
matchs = matchs[matchs['team2'].isin(teams)]

# %%
matchs.shape
# Out:
# (965, 20)

# %%
matchs['method'].value_counts()
# Out:
# method
# D/L    17
# Name: count, dtype: int64

# %%
match_df = matchs[matchs['method'] != 'D/L']

# %%
match_df
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1088  1426305     2024      Mumbai  2024-05-17       League         N Pooran
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
match_df= match_df[['id','city','winner','target_runs']]

# %%
match_df
# Out:
#            id        city                       winner  target_runs
# 0      335982   Bangalore        Kolkata Knight Riders        223.0
# 1      335983  Chandigarh          Chennai Super Kings        241.0
# 2      335984       Delhi             Delhi Daredevils        130.0
# 3      335985      Mumbai  Royal Challengers Bangalore        166.0
# 4      335986     Kolkata        Kolkata Knight Riders        111.0
# ...       ...         ...                          ...          ...
# 1088  1426305      Mumbai         Lucknow Super Giants        215.0
# 1090  1426307   Hyderabad          Sunrisers Hyderabad        215.0
# 1091  1426309   Ahmedabad        Kolkata Knight Riders        160.0
# 1093  1426311     Chennai          Sunrisers Hyderabad        176.0
# 1094  1426312     Chennai        Kolkata Knight Riders        114.0
#
# [948 rows x 4 columns]

# %%
delivery_df = match_df.merge(delivery, left_on='id', right_on='match_id')

# %%
delivery_df= delivery_df[delivery_df['inning'] ==2 ]

# %%
delivery_df.shape
# Out:
# (4678, 21)

# %%
delivery_df.head(2)
# Out:
#          id       city                 winner  target_runs  match_id  inning  \
# 124  335982  Bangalore  Kolkata Knight Riders        223.0    335982       2
# 125  335982  Bangalore  Kolkata Knight Riders        223.0    335982       2
#
#                     batting_team           bowling_team  over  ball  ...  \
# 124  Royal Challengers Bangalore  Kolkata Knight Riders   0.0   1.0  ...
# 125  Royal Challengers Bangalore  Kolkata Knight Riders   0.0   2.0  ...
#
#        bowler non_striker batsman_runs  extra_runs  total_runs  extras_type  \
# 124  AB Dinda    W Jaffer          1.0         0.0         1.0          NaN
# 125  AB Dinda    R Dravid          0.0         1.0         1.0        wides
#
#     is_wicket  player_dismissed dismissal_kind fielder
# 124       0.0               NaN            NaN     NaN
# 125       0.0               NaN            NaN     NaN
#
# [2 rows x 21 columns]

# %%
delivery_df['current_score']= delivery_df.groupby('id')['total_runs'].cumsum()

# %%
delivery_df['runs_left'] = delivery_df['target_runs'] - delivery_df['current_score']

# %%
delivery_df.head(2)
# Out:
#          id       city                 winner  target_runs  match_id  inning  \
# 124  335982  Bangalore  Kolkata Knight Riders        223.0    335982       2
# 125  335982  Bangalore  Kolkata Knight Riders        223.0    335982       2
#
#                     batting_team           bowling_team  over  ball  ...  \
# 124  Royal Challengers Bangalore  Kolkata Knight Riders   0.0   1.0  ...
# 125  Royal Challengers Bangalore  Kolkata Knight Riders   0.0   2.0  ...
#
#     batsman_runs extra_runs total_runs  extras_type  is_wicket  \
# 124          1.0        0.0        1.0          NaN        0.0
# 125          0.0        1.0        1.0        wides        0.0
#
#      player_dismissed dismissal_kind  fielder current_score runs_left
# 124               NaN            NaN      NaN           1.0     222.0
# 125               NaN            NaN      NaN           2.0     221.0
#
# [2 rows x 23 columns]

# %%
delivery_df['balls_left'] = 126 - (delivery_df['over']*6 + delivery_df['ball'])

# %%
delivery_df['player_dismissed'] = delivery_df['player_dismissed'].fillna('0')
delivery_df['player_dismissed'] = delivery_df['player_dismissed'].apply(lambda x:x if x == '0' else '1')
delivery_df['player_dismissed'] = delivery_df['player_dismissed'].astype('int')
wickets = delivery_df.groupby('id')['player_dismissed'].cumsum()
delivery_df['wickets'] = 10 - wickets
delivery_df
# Out:
#           id        city                 winner  target_runs  match_id  \
# 124   335982   Bangalore  Kolkata Knight Riders        223.0    335982
# 125   335982   Bangalore  Kolkata Knight Riders        223.0    335982
# 126   335982   Bangalore  Kolkata Knight Riders        223.0    335982
# 127   335982   Bangalore  Kolkata Knight Riders        223.0    335982
# 128   335982   Bangalore  Kolkata Knight Riders        223.0    335982
# ...      ...         ...                    ...          ...       ...
# 9872  336019  Chandigarh        Kings XI Punjab        222.0    336019
# 9873  336019  Chandigarh        Kings XI Punjab        222.0    336019
# 9874  336019  Chandigarh        Kings XI Punjab        222.0    336019
# 9875  336019  Chandigarh        Kings XI Punjab        222.0    336019
# 9876  336019  Chandigarh        Kings XI Punjab        222.0    336019
#
#       inning                 batting_team           bowling_team  over  ball  \
# ...

# %%
delivery_df.tail(4)
# Out:
#            id    city                       winner  target_runs  match_id  \
# 29648  419119  Mumbai  Royal Challengers Bangalore        152.0    419119
# 29649  419119  Mumbai  Royal Challengers Bangalore        152.0    419119
# 29650  419119  Mumbai  Royal Challengers Bangalore        152.0    419119
# 29651  419119  Mumbai  Royal Challengers Bangalore        152.0    419119
#
#        inning                 batting_team    bowling_team  over  ball  ...  \
# 29648       2  Royal Challengers Bangalore  Mumbai Indians  18.0   4.0  ...
# 29649       2  Royal Challengers Bangalore  Mumbai Indians  18.0   5.0  ...
# 29650       2  Royal Challengers Bangalore  Mumbai Indians  18.0   6.0  ...
# 29651       2  Royal Challengers Bangalore  Mumbai Indians  19.0   1.0  ...
#
#       total_runs extras_type is_wicket  player_dismissed  dismissal_kind  \
# 29648        0.0         NaN       0.0                 0             NaN
# ...

# %%
# crr = runs/over

# %%
delivery_df['crr'] = (delivery_df['current_score']*6)/(120 - delivery_df['balls_left'])

# %%
delivery_df['rrr'] = (delivery_df['runs_left']*6)/delivery_df['balls_left']

# %%
def result(row):
  return 1 if row['batting_team'] == row['winner'] else 0

# %%
delivery_df['result'] = delivery_df.apply(result,axis=1)

# %%
delivery_df.head(1)
# Out:
#          id       city                 winner  target_runs  match_id  inning  \
# 124  335982  Bangalore  Kolkata Knight Riders        223.0    335982       2
#
#                     batting_team           bowling_team  over  ball  ...  \
# 124  Royal Challengers Bangalore  Kolkata Knight Riders   0.0   1.0  ...
#
#     player_dismissed dismissal_kind fielder  current_score  runs_left  \
# 124                0            NaN     NaN            1.0      222.0
#
#      balls_left wickets  crr     rrr result
# 124       125.0      10 -1.2  10.656      0
#
# [1 rows x 28 columns]

# %%
final_df = delivery_df[['batting_team','bowling_team','city','runs_left',"balls_left","wickets","target_runs","crr","rrr","result"]]

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df.dropna(inplace=True)

# %%
final_df = final_df[final_df['balls_left'] != 0]

# %%
final_df.sample()
# Out:
#           batting_team         bowling_team     city  runs_left  balls_left  \
# 4723  Delhi Daredevils  Chennai Super Kings  Chennai       32.0        41.0
#
#       wickets  target_runs        crr       rrr  result
# 4723        9        170.0  10.481013  4.682927       1

# %%
X = final_df.iloc[:,:-1]
y = final_df.iloc[:,-1]
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

trf = ColumnTransformer(
    transformers=[
        ('trf', OneHotEncoder(sparse_output=False, drop='first'), ['batting_team', 'bowling_team', 'city'])
    ],
    remainder='passthrough'
)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',LogisticRegression(solver='liblinear'))
])

# %%
import numpy as np

X_train.replace([np.inf, -np.inf], np.nan, inplace=True)
X_train.dropna(inplace=True)
y_train = y_train.loc[X_train.index]  # Align target labels
# Remove negative 'runs_left' and negative 'rrr'
X_train = X_train[(X_train['runs_left'] >= 0) & (X_train['rrr'] >= 0)]
y_train = y_train.loc[X_train.index]

# %%
X_train.describe()
# Out:
#          runs_left   balls_left      wickets  target_runs          crr  \
# count  3699.000000  3699.000000  3699.000000  3699.000000  3699.000000
# mean     94.504461    70.861044     7.608273   167.155718     8.979565
# std      52.354304    32.243515     2.094146    34.000685     7.883321
# min       0.000000     5.000000     0.000000    68.000000   -72.000000
# 25%      52.000000    45.000000     6.000000   143.000000     7.426786
# 50%      92.000000    72.000000     8.000000   166.000000     8.839286
# 75%     133.000000    98.000000     9.000000   192.000000    10.135632
# max     237.000000   125.000000    10.000000   241.000000    84.000000
#
#                rrr
# count  3699.000000
# mean      8.411747
# std       4.809345
# min       0.000000
# 25%       5.849051
# 50%       7.816514
# 75%      10.099413
# max      67.000000

# %%
X_test.replace([np.inf, -np.inf], np.nan, inplace=True)
X_test.dropna(inplace=True)  # only if you don’t want to impute

pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['runs_left', 'balls_left',
#                                                    'wickets', 'target_runs',
#                                                    'crr', 'rrr']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
# ...

# %%
# 1. Replace inf with NaN (just as you did)
X_test.replace([np.inf, -np.inf], np.nan, inplace=True)

# 2. Drop NaNs and align y_test
X_test_clean = X_test.dropna()
y_test_clean = y_test.loc[X_test_clean.index]

# 3. Predict and evaluate
y_pred = pipe.predict(X_test_clean)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test_clean,y_pred)
# Out:
# 0.9935275080906149

# %%
probs = pipe.predict_proba(X_test)[:, 1]  # Probability of class 1 (e.g., "Team B wins")

# %%
pipe.predict_proba(X_test)
# Out:
# array([[4.20081326e-02, 9.57991867e-01],
#        [1.69894771e-07, 9.99999830e-01],
#        [2.19647425e-04, 9.99780353e-01],
#        ...,
#        [7.63466902e-03, 9.92365331e-01],
#        [6.82626116e-08, 9.99999932e-01],
#        [1.09023759e-02, 9.89097624e-01]])

# %%
 def match_summary(row):
    print("Batting Team-" + row['batting_team'] + " | Bowling Team-" + row['bowling_team'] + " | Target- " + str(row['target_runs']))

# %%
def match_progression(x_df,match_id,pipe):
    match = x_df[x_df['match_id'] == match_id]
    match = match[(match['ball'] == 6)]
    temp_df = match[['batting_team','bowling_team','city','runs_left',"balls_left","wickets","target_runs","crr","rrr","result"]].dropna()
    temp_df = temp_df[temp_df['balls_left'] != 0]
    result = pipe.predict_proba(temp_df)
    temp_df['lose'] = np.round(result.T[0]*100,1)
    temp_df['win'] = np.round(result.T[1]*100,1)
    temp_df['end_of_over'] = range(1,temp_df.shape[0]+1)

    target = temp_df['total_runs'].values[0]
    runs = list(temp_df['runs_left'].values)
    new_runs = runs[:]
    runs.insert(0,target)
    temp_df['runs_after_over'] = np.array(runs)[:-1] - np.array(new_runs)
    wickets = list(temp_df['wickets'].values)
    new_wickets = wickets[:]
    new_wickets.insert(0,10)
    wickets.append(0)
    w = np.array(wickets)
    nw = np.array(new_wickets)
    temp_df['wickets_in_over'] = (nw - w)[0:temp_df.shape[0]]

    print("Target-",target)
    temp_df = temp_df[['end_of_over','runs_after_over','wickets_in_over','lose','win']]
    return temp_df,target

# %%
def match_progression(df, pipe):
    # preprocessing steps
    X = prepare_input(df)  # hypothetical step

    if X.shape[0] == 0:
        print("❌ No valid input rows to predict.")
        return pd.DataFrame(), None

    probs = pipe.predict_proba(X)[:,1]  # Get win probabilities
    df['win_prob'] = probs

    return df, probs

# %%
temp_df,target = match_progression(delivery_df,74,pipe)
temp_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-25aae16ad1b0> in <cell line: 0>()
# ----> 1 temp_df,target = match_progression(delivery_df,74,pipe)
#       2 temp_df
#
# TypeError: match_progression() takes 2 positional arguments but 3 were given
